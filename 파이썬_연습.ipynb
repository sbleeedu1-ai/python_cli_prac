# %% [markdown]
# <a href="https://colab.research.google.com/github/sbleeedu1-ai/python_cli_prac/blob/main/%ED%8C%8C%EC%9D%B4%EC%8D%AC_%EC%97%B0%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
article_num = 0
articles = []

print("== CLI 게시판 실행 ==")

while True:
  cmd = input("명령어 ) ")

  if cmd == 'article write':
    article_num += 1
    title = input("제목 : ")
    body = input("내용 : ")
    article = [article_num, title, body]

    articles.append(article)
    print(f"{article_num} 번 글이 생성 되었습니다.")

  elif cmd == 'article list':
    print("=======================================")
    print("번호".ljust(6)+"/",end='')
    print("제목".center(13)+"/",end='')
    print("내용".rjust(8))
    for i in range(len(articles)-1,-1,-1):
      print(f"{articles[i][0]}".ljust(8)+"/",end='')
      print(f"{articles[i][1]}".center(15)+"/",end='')
      print(f"{articles[i][2]}".rjust(8))
    print("=======================================")

  elif cmd.startswith('article delete'):
    cmd_bit = cmd[14:].strip()
    # 입력된 문자 잘라서 받기 (자동 공백제거)

    if cmd_bit == '':
      print("입력된 글 번호가 없습니다.")
      continue

    if not cmd_bit.isdigit():
      print("글 번호가 아닙니다.")
      continue
    # 명령어 이후 번호가 없거나 다른게 입력되면 다시 재입력

    article_exist = False
    for i in range(0,len(articles)):
      if int(cmd_bit) == i+1:
        a = articles[i]
        article_exist = True
        break
    # 글 존재 여부 체크

    if article_exist == False:
      print(f"{cmd_bit} 번 글이 존재하지 않습니다.")
      continue
    # 없다면 다시 명령어로

    articles.remove(a)
    print(f"{cmd_bit} 번 글이 삭제 되었습니다.")

  if cmd == 'exit':
    break

print("== CLI 게시판 종료 ==")
# Out:
# == CLI 게시판 실행 ==
# 명령어 ) article write
# 제목 : 123
# 내용 : abc
# 1 번 글이 생성 되었습니다.
# 명령어 ) article write
# 제목 : 456
# 내용 : def
# 2 번 글이 생성 되었습니다.
# 명령어 ) article list
# =======================================
# 번호    /      제목     /      내용
# 2       /      456      /     def
# 1       /      123      /     abc
# =======================================
# 명령어 ) article delete 3
# 3 번 글이 존재하지 않습니다.
# 명령어 ) article delete 1
# 1 번 글이 삭제 되었습니다.
# 명령어 ) article list
# =======================================
# 번호    /      제목     /      내용
# 2       /      456      /     def
# =======================================
# 명령어 ) exit
# == CLI 게시판 종료 ==
